# %% [markdown]
# # Statistical Models: Interest Group Prominence in Congressional Speech
#
# **Author:** Kaleb Mazurek
# **Thesis:** MSc Social Science Research, University of Amsterdam, 2023
#
# Three sets of mixed-effects logistic regression models testing what predicts whether an interest group mention is prominent (cited as authoritative) versus routine.
#
# - **Model A**: Does issue salience predict prominence?
# - **Model B**: Do politician characteristics predict prominence?
# - **Model C**: Do organizational resources predict prominence?
#
# Random effects: Organization ID and Policy Area (crossed).
#
# Note: The primary inferential models were run in R (`03_Multilevel_Models.Rmd`). This notebook implements the same models in Python using statsmodels for comparison.

# %% [markdown]
# ## Setup and Dependencies

# %%
# Install required packages (uncomment if needed)
# !pip install pandas numpy statsmodels scipy matplotlib seaborn
# !pip install patsy scikit-learn tableone openpyxl

# %%
# Core libraries
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Statistical modeling
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod import families
from scipy import stats

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Table formatting
from IPython.display import display, HTML

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Set plotting style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('colorblind')

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# ## Configuration

# %%
# Configuration class for project settings
class Config:
    """Project configuration settings"""
    
    # File paths (relative to analysis/ directory)
    DATA_DIR = Path("../data/multi_level_data")
    OUTPUT_DIR = Path("../output/figures")
    
    # Data file
    LEVEL1_FILE = DATA_DIR / "level1_FINAL.csv"
    
    # Organization to exclude (if any)
    EXCLUDED_ORG_ID = None
    
    # Random seed for reproducibility
    RANDOM_SEED = 42
    
    # Reference categories for factors
    REF_CHAMBER = "House of Representatives"
    REF_PARTY = "Democrat"
    REF_MEMBERSHIP = "Association of Institutions"
    REF_CATEGORY = "Business Interests"

config = Config()
config.OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"Data directory: {config.DATA_DIR.resolve()}")
print(f"Output directory: {config.OUTPUT_DIR.resolve()}")
print(f"Data file: {config.LEVEL1_FILE}")
# Out:
# Data directory: C:\Users\kaleb\OneDrive\Documents\GitHub\MastersThesis_InterestGroupAnalysis\data\multi_level_data
# Output directory: C:\Users\kaleb\OneDrive\Documents\GitHub\MastersThesis_InterestGroupAnalysis\output\figures
# Data file: ..\data\multi_level_data\level1_FINAL.csv

# %% [markdown]
# ---
#
# # Data Loading and Preprocessing
#
# This section handles all data loading and transformation steps that are common across all models.

# %%
def load_data(filepath: Path, excluded_org_id: int = None) -> pd.DataFrame:
    """
    Load the level1 dataset and perform initial filtering.
    
    Parameters
    ----------
    filepath : Path
        Path to the CSV file
    excluded_org_id : int, optional
        Organization ID to exclude from analysis
        
    Returns
    -------
    pd.DataFrame
        Loaded and filtered dataframe
    """
    df = pd.read_csv(filepath)
    
    if excluded_org_id:
        df = df[df['level1_org_id'] != excluded_org_id].copy()
        
    print(f"Loaded {len(df):,} rows")
    return df

# %%
def recode_abbrevcat(df: pd.DataFrame) -> pd.DataFrame:
    """
    Recode the ABBREVCAT (organization category) variable.
    
    Original categories are renamed and collapsed into broader groupings:
    - Business Interests
    - Government Interests  
    - Non-Business Interests
    """
    df = df.copy()
    
    # Original to readable name mapping
    name_mapping = {
        "(1) Corporations": "Corporations",
        "(13) Social welfare or poor": "Social Welfare or Poor",
        "(14) State and local governments": "State and Local Governments",
        "(16) Other": "Other",
        "(2) Trade and other business associations": "Trade and Business Associations",
        "(3) Occupational associations": "Occupational Associations",
        "(4) Unions": "Unions",
        "(5) Education": "Education",
        "(6) Health": "Health",
        "(7) Public interest": "Public Interest",
        "(8) Identity groups": "Identity Groups"
    }
    
    # Apply initial renaming
    df['level1_ABBREVCAT'] = df['level1_ABBREVCAT'].map(name_mapping)
    
    # Remove Corporations (as in original R code)
    df = df[df['level1_ABBREVCAT'] != 'Corporations'].copy()
    
    # Collapse into broader categories
    collapse_mapping = {
        "Trade and Business Associations": "Business-Oriented Interests",
        "Corporations": "Business-Oriented Interests",
        "State and Local Governments": "Government Interests",
        "Unions": "Non-business/nongovernment",
        "Education": "Non-business/nongovernment",
        "Health": "Non-business/nongovernment",
        "Social Welfare or Poor": "Non-business/nongovernment",
        "Public Interest": "Non-business/nongovernment",
        "Identity Groups": "Non-business/nongovernment",
        "Occupational Associations": "Non-business/nongovernment",
        "Other": "Non-business/nongovernment"
    }
    
    df['level1_ABBREVCAT'] = df['level1_ABBREVCAT'].map(collapse_mapping)
    
    # Further collapse for final analysis
    final_mapping = {
        "Business-Oriented Interests": "Business Interests",
        "Government Interests": "Government Interests",
        "Non-business/nongovernment": "Non-Business Interests"
    }
    
    df['level1_ABBREVCAT'] = df['level1_ABBREVCAT'].map(final_mapping).fillna("Non-Business Interests")
    
    # Create binary business interest indicator
    df['business_interest'] = (df['level1_ABBREVCAT'] == 'Business Interests').astype(int)
    
    print(f"ABBREVCAT categories: {df['level1_ABBREVCAT'].value_counts().to_dict()}")
    
    return df

# %%
def recode_membership_status(df: pd.DataFrame) -> pd.DataFrame:
    """
    Recode the MSHIP_STATUS11 (membership status) variable.
    
    Categories are collapsed into:
    - Association of Individuals
    - Association of Institutions
    - Other
    """
    df = df.copy()
    
    # Original to readable name mapping
    name_mapping = {
        "(1) Institution": "Institution",
        "(2) Association of individuals": "Association of Individuals",
        "(3) Association of institutions": "Association of Institutions",
        "(4) Government or association of governments": "Government or Association of Governments",
        "(5) Mixed": "Mixed",
        "(6) Other": "Other",
        "(9) Cant tell or DK": "Can't Tell"
    }
    
    df['level1_MSHIP_STATUS11'] = df['level1_MSHIP_STATUS11'].map(name_mapping)
    
    # Collapse categories
    collapse_mapping = {
        "Association of Individuals": "Association of Individuals",
        "Institution": "Association of Institutions",
        "Association of Institutions": "Association of Institutions",
        "Government or Association of Governments": "Association of Institutions",
        "Mixed": "Other",
        "Other": "Other",
        "Can't Tell": "Other"
    }
    
    df['level1_MSHIP_STATUS11'] = df['level1_MSHIP_STATUS11'].map(collapse_mapping).fillna("Other")
    
    print(f"Membership status categories: {df['level1_MSHIP_STATUS11'].value_counts().to_dict()}")
    
    return df

# %%
def create_term_status(df: pd.DataFrame) -> pd.DataFrame:
    """
    Create term status variable indicating position in electoral cycle.
    """
    df = df.copy()
    
    # Extract mention year from year_week column, handling NaN
    df['mention_year'] = pd.to_numeric(
        df['level1_year_week'].astype(str).str[:4].replace('nan', np.nan),
        errors='coerce'
    )
    
    # Create indicators (only where mention_year is not NaN)
    df['year_before_termEnd'] = (
        (df['mention_year'].notna()) & 
        (df['mention_year'] == (df['level1_termEndYear'] - 1))
    ).astype(int)
    
    df['first_year_term'] = (
        (df['mention_year'].notna()) & 
        (df['mention_year'] == df['level1_termBeginYear'])
    ).astype(int)
    
    # Create term_status categorical
    def assign_term_status(row):
        if pd.isna(row.get('mention_year')):
            return np.nan
        if row['first_year_term'] == 1 and row['year_before_termEnd'] == 0:
            return "First Year"
        elif row['first_year_term'] == 0 and row['year_before_termEnd'] == 1:
            return "Year Before Term End"
        else:
            return "Other"
    
    df['term_status'] = df.apply(assign_term_status, axis=1)
    
    print(f"Term status distribution: {df['term_status'].value_counts().to_dict()}")
    
    return df

# %%
def compute_issue_area_features(df: pd.DataFrame) -> pd.DataFrame:
    """
    Compute issue area related features for each organization.
    
    Creates:
    - most_common_issue_area: Mode of issue areas for each org
    - unique_issue_areas: Count of distinct issue areas per org
    - issue_area_overlap: Whether mention is in org's most common area
    """
    df = df.copy()
    
    # Compute most common issue area per organization
    most_common = df.groupby('level1_org_id')['level1_issue_area'].agg(
        lambda x: x.mode().iloc[0] if len(x.mode()) > 0 else np.nan
    ).reset_index()
    most_common.columns = ['level1_org_id', 'most_common_issue_area']
    
    # Compute unique issue areas per organization
    unique_areas = df.groupby('level1_org_id')['level1_issue_area'].nunique().reset_index()
    unique_areas.columns = ['level1_org_id', 'unique_issue_areas']
    
    # Merge back to main dataframe
    df = df.merge(most_common, on='level1_org_id', how='left')
    df = df.merge(unique_areas, on='level1_org_id', how='left')
    
    # Create overlap indicator
    df['issue_area_overlap'] = (df['level1_issue_area'] == df['most_common_issue_area']).astype(int)
    
    print(f"Mean unique issue areas per org: {df['unique_issue_areas'].mean():.2f}")
    
    return df

# %%
def compute_saliency_measure(df: pd.DataFrame) -> pd.DataFrame:
    """
    Compute saliency categories from the existing issue_area_salience column.
    Categories: low (1-7), medium (8-14), high (15+)
    """
    df = df.copy()
    
    # Use the existing saliency column from the dataset
    df['saliency_measure'] = pd.to_numeric(df['level1_issue_area_salience'], errors='coerce')
    
    # Create categorical saliency (low, medium, high)
    def categorize_saliency(val):
        if pd.isna(val):
            return np.nan
        if val <= 7:
            return 'low'
        elif val <= 14:
            return 'medium'
        else:
            return 'high'
    
    df['saliency_category'] = df['saliency_measure'].apply(categorize_saliency)
    
    print(f"Saliency distribution: {df['saliency_category'].value_counts().to_dict()}")
    
    return df

# %%
def clean_categorical_variables(df: pd.DataFrame) -> pd.DataFrame:
    """
    Clean and prepare categorical variables for modeling.
    
    - Converts empty strings to NaN
    - Sets up categorical dtypes
    """
    df = df.copy()
    
    # Replace empty strings with NaN
    string_cols = ['level1_chamber_x', 'level1_partyHistory']
    for col in string_cols:
        if col in df.columns:
            df[col] = df[col].replace('', np.nan)
    
    # Convert to categorical
    categorical_cols = [
        'level1_chamber_x', 'level1_partyHistory', 'saliency_category',
        'level1_issue_area', 'level1_ABBREVCAT', 'level1_MSHIP_STATUS11',
        'term_status'
    ]
    
    for col in categorical_cols:
        if col in df.columns:
            df[col] = pd.Categorical(df[col])
    
    return df

# %%
def preprocess_data(filepath: Path, excluded_org_id: int = None) -> pd.DataFrame:
    """
    Complete data preprocessing pipeline.
    
    Chains all preprocessing steps together.
    """
    print("="*60)
    print("DATA PREPROCESSING PIPELINE")
    print("="*60)
    
    # Load data
    print("\n[1/7] Loading data...")
    df = load_data(filepath, excluded_org_id)
    
    # Recode organization categories
    print("\n[2/7] Recoding organization categories...")
    df = recode_abbrevcat(df)
    
    # Recode membership status
    print("\n[3/7] Recoding membership status...")
    df = recode_membership_status(df)
    
    # Create term status
    print("\n[4/7] Creating term status...")
    df = create_term_status(df)
    
    # Compute issue area features
    print("\n[5/7] Computing issue area features...")
    df = compute_issue_area_features(df)
    
    # Compute saliency measure
    print("\n[6/7] Computing saliency measure...")
    df = compute_saliency_measure(df)
    
    # Clean categorical variables
    print("\n[7/7] Cleaning categorical variables...")
    df = clean_categorical_variables(df)
    
    print("\n" + "="*60)
    print(f"Preprocessing complete. Final dataset: {len(df):,} rows, {len(df.columns)} columns")
    print("="*60)
    
    return df

# %% [markdown]
# ---
#
# # Model Utilities
#
# Helper functions for fitting and evaluating mixed-effects models.

# %%
def fit_mixed_model(formula: str, data: pd.DataFrame, groups: str, 
                    model_name: str = "model") -> dict:
    """
    Fit a mixed-effects logistic regression model.
    
    Note: Python's statsmodels uses a different approach than R's lme4.
    For true multilevel models with crossed random effects, consider
    using pymer4 or rpy2 to call R's lme4 directly.
    
    Parameters
    ----------
    formula : str
        Model formula (Patsy/R-style)
    data : pd.DataFrame
        Input data
    groups : str
        Column name for random effects grouping
    model_name : str
        Name for the model
        
    Returns
    -------
    dict
        Dictionary containing model results
    """
    try:
        # Fit mixed-effects model
        model = smf.mixedlm(formula, data, groups=data[groups])
        result = model.fit(method='lbfgs', maxiter=1000)
        
        # Calculate statistics
        llf = result.llf
        nobs = result.nobs
        k = len(result.params)
        
        aic = -2 * llf + 2 * k
        bic = -2 * llf + np.log(nobs) * k
        
        # Get coefficients and odds ratios
        params = result.params
        conf_int = result.conf_int()
        pvalues = result.pvalues
        
        # Create summary dataframe
        summary_df = pd.DataFrame({
            'term': params.index,
            'estimate': params.values,
            'std_error': result.bse.values,
            'z_value': result.tvalues.values,
            'p_value': pvalues.values,
            'odds_ratio': np.exp(params.values),
            'ci_lower': conf_int.iloc[:, 0].values,
            'ci_upper': conf_int.iloc[:, 1].values
        })
        summary_df['model'] = model_name
        
        return {
            'model': result,
            'name': model_name,
            'formula': formula,
            'llf': llf,
            'aic': aic,
            'bic': bic,
            'nobs': nobs,
            'summary_df': summary_df,
            'converged': result.converged
        }
        
    except Exception as e:
        print(f"Error fitting model {model_name}: {e}")
        return None

# %%
def fit_glm_logistic(formula: str, data: pd.DataFrame, model_name: str = "model") -> dict:
    """
    Fit a standard logistic regression model (without random effects).
    
    This is a simpler alternative when mixed-effects models fail to converge
    or when random effects are not essential.
    
    Parameters
    ----------
    formula : str
        Model formula
    data : pd.DataFrame
        Input data
    model_name : str
        Name for the model
        
    Returns
    -------
    dict
        Dictionary containing model results
    """
    try:
        # Fit GLM with binomial family (logistic regression)
        model = smf.glm(formula, data, family=sm.families.Binomial())
        result = model.fit()
        
        # Get coefficients and statistics
        params = result.params
        conf_int = result.conf_int()
        
        # Create summary dataframe
        summary_df = pd.DataFrame({
            'term': params.index,
            'estimate': params.values,
            'std_error': result.bse.values,
            'z_value': result.tvalues.values,
            'p_value': result.pvalues.values,
            'odds_ratio': np.exp(params.values),
            'ci_lower': conf_int.iloc[:, 0].values,
            'ci_upper': conf_int.iloc[:, 1].values
        })
        summary_df['model'] = model_name
        
        return {
            'model': result,
            'name': model_name,
            'formula': formula,
            'llf': result.llf,
            'aic': result.aic,
            'bic': result.bic,
            'nobs': result.nobs,
            'summary_df': summary_df,
            'converged': True
        }
        
    except Exception as e:
        print(f"Error fitting model {model_name}: {e}")
        return None

# %%
def print_model_summary(result: dict):
    """
    Print a formatted summary of model results.
    """
    if result is None:
        print("Model fitting failed.")
        return
    
    print("\n" + "="*70)
    print(f"MODEL: {result['name']}")
    print("="*70)
    
    print(f"\nFormula: {result['formula']}")
    print(f"\nModel Fit Statistics:")
    print(f"  Log-Likelihood: {result['llf']:.2f}")
    print(f"  AIC: {result['aic']:.2f}")
    print(f"  BIC: {result['bic']:.2f}")
    print(f"  N observations: {result['nobs']:,}")
    print(f"  Converged: {result['converged']}")
    
    print("\nFixed Effects (Odds Ratios):")
    print("-"*70)
    
    df = result['summary_df'].copy()
    df['odds_ratio'] = df['odds_ratio'].round(4)
    df['p_value'] = df['p_value'].round(4)
    df['significance'] = df['p_value'].apply(
        lambda p: '***' if p < 0.001 else '**' if p < 0.01 else '*' if p < 0.05 else '.' if p < 0.1 else ''
    )
    
    for _, row in df.iterrows():
        print(f"  {row['term']:<40} OR: {row['odds_ratio']:>8.4f}  p: {row['p_value']:>7.4f} {row['significance']}")
    
    print("\nSignif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1")

# %%
def compare_models(models: list) -> pd.DataFrame:
    """
    Create a comparison table of model fit statistics.
    """
    rows = []
    for m in models:
        if m is None:
            continue
        rows.append({
            'Model': m['name'],
            'Log-Likelihood': m['llf'],
            'AIC': m['aic'],
            'BIC': m['bic'],
            'N': m['nobs'],
            'Pseudo R2': m.get('pseudo_r2', np.nan)
        })
    return pd.DataFrame(rows)

# %% [markdown]
# # Model A: Issue Salience
#
# Are interest groups mentioned in high-salience policy areas more likely to be cited prominently? Salience measured via Google Trends data aggregated by CAP policy domain.

# %%
def create_coefficient_plot(models: list, figsize=(12, 8)):
    """
    Create a coefficient plot (forest plot) for model comparison.
    """
    fig, ax = plt.subplots(figsize=figsize)
    
    colors = plt.cm.Set2(np.linspace(0, 1, len(models)))
    y_offset = 0
    y_positions = []
    y_labels = []
    
    for i, m in enumerate(models):
        if m is None:
            continue
            
        df = m['summary_df']
        # Exclude intercept and random effects for visualization
        df = df[~df['term'].str.contains('Intercept|Group Var', case=False)]
        
        for j, (_, row) in enumerate(df.iterrows()):
            y_pos = y_offset + j
            
            # Plot point estimate and confidence interval
            ax.errorbar(
                row['odds_ratio'], y_pos,
                xerr=[[row['odds_ratio'] - np.exp(row['ci_lower'])],
                      [np.exp(row['ci_upper']) - row['odds_ratio']]],
                fmt='o', color=colors[i], capsize=3,
                label=m['name'] if j == 0 else None
            )
            
            y_positions.append(y_pos)
            y_labels.append(f"{row['term']} ({m['name']})")
        
        y_offset += len(df) + 1
    
    # Add reference line at OR = 1
    ax.axvline(x=1, color='red', linestyle='--', alpha=0.5, label='OR = 1')
    
    ax.set_yticks(y_positions)
    ax.set_yticklabels(y_labels, fontsize=8)
    ax.set_xlabel('Odds Ratio')
    ax.set_title('Coefficient Plot (Odds Ratios with 95% CI)')
    ax.legend(loc='best')
    
    plt.tight_layout()
    return fig

# %%
# Load and preprocess real data
print("Loading data from:", config.LEVEL1_FILE)
level1 = preprocess_data(config.LEVEL1_FILE, config.EXCLUDED_ORG_ID)
print()
print(f"Final dataset: {len(level1):,} rows, {level1.shape[1]} columns")
# Out:
# Loading data from: ..\data\multi_level_data\level1_FINAL.csv
# ============================================================
# DATA PREPROCESSING PIPELINE
# ============================================================
#
# [1/7] Loading data...
# Loaded 22,414 rows
#
# [2/7] Recoding organization categories...
# ABBREVCAT categories: {'Non-Business Interests': 18679, 'Business Interests': 3200, 'Government Interests': 532}
#
# [3/7] Recoding membership status...
# Membership status categories: {'Association of Individuals': 11353, 'Association of Institutions': 9767, 'Other': 1291}
#
# [4/7] Creating term status...
# Term status distribution: {'Other': 7868, 'First Year': 6705, 'Year Before Term End': 4418}
#
# [5/7] Computing issue area features...
# Mean unique issue areas per org: 6.87
#
# [6/7] Computing saliency measure...
# Saliency distribution: {'low': 6512, 'high': 6027, 'medium': 1851}
#
# [7/7] Cleaning categorical variables...
#
# ============================================================
# Preprocessing complete. Final dataset: 22,411 rows, 185 columns
# ============================================================
#
# Final dataset: 22,411 rows, 185 columns

# %%
# Examine the data
print("\nData Summary:")
print("="*60)
print(f"\nProminence distribution:")
print(level1['level1_prominence'].value_counts(normalize=True))

print(f"\nSaliency category distribution:")
print(level1['saliency_category'].value_counts())

print(f"\nChamber distribution:")
print(level1['level1_chamber_x'].value_counts())

print(f"\nParty distribution:")
print(level1['level1_partyHistory'].value_counts())
# Out:
# Data Summary:
# ============================================================
#
# Prominence distribution:
# level1_prominence
# 0.0000   0.5331
# 1.0000   0.4669
# Name: proportion, dtype: float64
#
# Saliency category distribution:
# saliency_category
# low       6512
# high      6027
# medium    1851
# Name: count, dtype: int64
#
# Chamber distribution:
# level1_chamber_x
# Senate                      5667
# House of Representatives    5540
# Name: count, dtype: int64
#
# Party distribution:
# level1_partyHistory
# Democrat       6062
# Republican     4996
# Independent     149
# Name: count, dtype: int64

# %% [markdown]
# ### Model A - Empty Model (Intercept Only)

# %%
# Fit empty model (intercept only)
empty_model_a = fit_glm_logistic(
    formula="level1_prominence ~ 1",
    data=level1,
    model_name="Empty Model A"
)

print_model_summary(empty_model_a)
# Out:
# ======================================================================
# MODEL: Empty Model A
# ======================================================================
#
# Formula: level1_prominence ~ 1
#
# Model Fit Statistics:
#   Log-Likelihood: -13121.93
#   AIC: 26245.86
#   BIC: -160840.32
#   N observations: 18,991
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   0.8758  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model A1 - Saliency Category Only

# %%
# Model 1: Saliency category
model_a1 = fit_glm_logistic(
    formula="level1_prominence ~ C(saliency_category, Treatment('low'))",
    data=level1,
    model_name="Model A1 (Saliency)"
)

print_model_summary(model_a1)
# Out:
# ======================================================================
# MODEL: Model A1 (Saliency)
# ======================================================================
#
# Formula: level1_prominence ~ C(saliency_category, Treatment('low'))
#
# Model Fit Statistics:
#   Log-Likelihood: -9813.95
#   AIC: 19633.91
#   BIC: -118117.38
#   N observations: 14,390
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   0.6545  p:  0.0000 ***
#   C(saliency_category, Treatment('low'))[T.high] OR:   1.3187  p:  0.0000 ***
#   C(saliency_category, Treatment('low'))[T.medium] OR:   1.4274  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model A2 - Full Model with Controls

# %%
# Model 2: Full model with controls
model_a2 = fit_glm_logistic(
    formula="""level1_prominence ~ 
        C(saliency_category, Treatment('low')) + 
        C(level1_chamber_x, Treatment('House of Representatives')) + 
        C(level1_partyHistory, Treatment('Democrat')) + 
        C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) + 
        C(level1_ABBREVCAT, Treatment('Business Interests'))""",
    data=level1.dropna(subset=["level1_prominence", "saliency_category", "level1_chamber_x", "level1_partyHistory", "level1_MSHIP_STATUS11", "level1_ABBREVCAT"]),
    model_name="Model A2 (Full)"
)

print_model_summary(model_a2)
# Out:
# ======================================================================
# MODEL: Model A2 (Full)
# ======================================================================
#
# Formula: level1_prominence ~
#         C(saliency_category, Treatment('low')) +
#         C(level1_chamber_x, Treatment('House of Representatives')) +
#         C(level1_partyHistory, Treatment('Democrat')) +
#         C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) +
#         C(level1_ABBREVCAT, Treatment('Business Interests'))
#
# Model Fit Statistics:
#   Log-Likelihood: -4963.04
#   AIC: 9946.08
#   BIC: -55536.77
#   N observations: 7,362
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   1.6734  p:  0.0000 ***
#   C(saliency_category, Treatment('low'))[T.high] OR:   1.0192  p:  0.7125
#   C(saliency_category, Treatment('low'))[T.medium] OR:   1.2776  p:  0.0015 **
#   C(level1_chamber_x, Treatment('House of Representatives'))[T.Senate] OR:   1.1752  p:  0.0010 **
#   C(level1_partyHistory, Treatment('Democrat'))[T.Independent] OR:   0.6794  p:  0.1292
#   C(level1_partyHistory, Treatment('Democrat'))[T.Republican] OR:   0.9491  p:  0.2809
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Association of Individuals] OR:   0.7485  p:  0.0000 ***
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Other] OR:   1.0153  p:  0.8933
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Government Interests] OR:   0.7475  p:  0.0792 .
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Non-Business Interests] OR:   0.9102  p:  0.2814
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ---
#
# # Model B: Politician Characteristics
#
# Do politician-level factors (seniority, party, chamber, legislative activity) predict whether they cite interest groups as authoritative voices?

# %% [markdown]
# ### Model A - Comparison Table

# %%
# Compare models
model_a_comparison = compare_models([empty_model_a, model_a1, model_a2])
print("\nModel A Comparison:")
print("="*70)
display(model_a_comparison.round(2))
# Out:
# Model A Comparison:
# ======================================================================
#                  Model  Log-Likelihood        AIC          BIC      N  \
# 0        Empty Model A     -13121.9300 26245.8600 -160840.3200  18991
# 1  Model A1 (Saliency)      -9813.9500 19633.9100 -118117.3800  14390
# 2      Model A2 (Full)      -4963.0400  9946.0800  -55536.7700   7362
#
#    Pseudo R2
# 0        NaN
# 1        NaN
# 2        NaN

# %% [markdown]
# ### Model B - Empty Model

# %%
# Empty model for Model B
empty_model_b = fit_glm_logistic(
    formula="level1_prominence ~ 1",
    data=level1,
    model_name="Empty Model B"
)

print_model_summary(empty_model_b)
# Out:
# ======================================================================
# MODEL: Empty Model B
# ======================================================================
#
# Formula: level1_prominence ~ 1
#
# Model Fit Statistics:
#   Log-Likelihood: -13121.93
#   AIC: 26245.86
#   BIC: -160840.32
#   N observations: 18,991
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   0.8758  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model B1 - Politician Characteristics

# %%
# Model B1: Politician characteristics
model_b1 = fit_glm_logistic(
    formula="""level1_prominence ~ 
        level1_issue_maximal_overlap + 
        C(term_status, Treatment('First Year')) + 
        level1_bills_sponsored + 
        level1_seniority""",
    data=level1.dropna(subset=["level1_prominence", "level1_issue_maximal_overlap", "term_status", "level1_bills_sponsored", "level1_seniority"]),
    model_name="Model B1 (Politician Chars)"
)

print_model_summary(model_b1)
# Out:
# ======================================================================
# MODEL: Model B1 (Politician Chars)
# ======================================================================
#
# Formula: level1_prominence ~
#         level1_issue_maximal_overlap +
#         C(term_status, Treatment('First Year')) +
#         level1_bills_sponsored +
#         level1_seniority
#
# Model Fit Statistics:
#   Log-Likelihood: -4904.70
#   AIC: 9821.39
#   BIC: -54798.33
#   N observations: 7,272
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   1.4011  p:  0.0000 ***
#   C(term_status, Treatment('First Year'))[T.Other] OR:   1.1012  p:  0.7618
#   C(term_status, Treatment('First Year'))[T.Year Before Term End] OR:   1.2317  p:  0.0000 ***
#   level1_issue_maximal_overlap             OR:   1.1070  p:  0.0834 .
#   level1_bills_sponsored                   OR:   1.0036  p:  0.0006 ***
#   level1_seniority                         OR:   0.9848  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model B2 - Full Model with Controls

# %% [markdown]
# ---
#
# # Model C: Organizational Resources
#
# Do organizational characteristics (age, lobbying expenditure, policy scope, use of external lobbyists) predict legislative prominence?

# %%
# Model B2: Full model with controls
model_b2 = fit_glm_logistic(
    formula="""level1_prominence ~ 
        level1_issue_maximal_overlap + 
        C(term_status, Treatment('First Year')) + 
        level1_bills_sponsored + 
        level1_seniority + 
        C(level1_chamber_x, Treatment('House of Representatives')) + 
        C(level1_partyHistory, Treatment('Democrat')) + 
        C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) + 
        C(level1_ABBREVCAT, Treatment('Business Interests'))""",
    data=level1.dropna(subset=["level1_prominence", "level1_issue_maximal_overlap", "term_status", "level1_bills_sponsored", "level1_seniority", "level1_chamber_x", "level1_partyHistory", "level1_MSHIP_STATUS11", "level1_ABBREVCAT"]),
    model_name="Model B2 (Full)"
)

print_model_summary(model_b2)
# Out:
# ======================================================================
# MODEL: Model B2 (Full)
# ======================================================================
#
# Formula: level1_prominence ~
#         level1_issue_maximal_overlap +
#         C(term_status, Treatment('First Year')) +
#         level1_bills_sponsored +
#         level1_seniority +
#         C(level1_chamber_x, Treatment('House of Representatives')) +
#         C(level1_partyHistory, Treatment('Democrat')) +
#         C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) +
#         C(level1_ABBREVCAT, Treatment('Business Interests'))
#
# Model Fit Statistics:
#   Log-Likelihood: -4874.76
#   AIC: 9775.52
#   BIC: -54795.96
#   N observations: 7,272
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   1.9730  p:  0.0000 ***
#   C(term_status, Treatment('First Year'))[T.Other] OR:   1.0710  p:  0.8300
#   C(term_status, Treatment('First Year'))[T.Year Before Term End] OR:   1.2085  p:  0.0002 ***
#   C(level1_chamber_x, Treatment('House of Representatives'))[T.Senate] OR:   1.1781  p:  0.0048 **
#   C(level1_partyHistory, Treatment('Democrat'))[T.Independent] OR:   0.6437  p:  0.0869 .
#   C(level1_partyHistory, Treatment('Democrat'))[T.Republican] OR:   0.8923  p:  0.0230 *
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Association of Individuals] OR:   0.7326  p:  0.0000 ***
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Other] OR:   1.0368  p:  0.7522
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Government Interests] OR:   0.7886  p:  0.1552
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Non-Business Interests] OR:   0.9326  p:  0.4285
#   level1_issue_maximal_overlap             OR:   1.1133  p:  0.0703 .
#   level1_bills_sponsored                   OR:   1.0013  p:  0.2740
#   level1_seniority                         OR:   0.9835  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model B - Comparison Table

# %%
# Compare models
model_b_comparison = compare_models([empty_model_b, model_b1, model_b2])
print("\nModel B Comparison:")
print("="*70)
display(model_b_comparison.round(2))
# Out:
# Model B Comparison:
# ======================================================================
#                          Model  Log-Likelihood        AIC          BIC      N  \
# 0                Empty Model B     -13121.9300 26245.8600 -160840.3200  18991
# 1  Model B1 (Politician Chars)      -4904.7000  9821.3900  -54798.3300   7272
# 2              Model B2 (Full)      -4874.7600  9775.5200  -54795.9600   7272
#
#    Pseudo R2
# 0        NaN
# 1        NaN
# 2        NaN

# %% [markdown]
# ### Model C - Empty Model

# %%
# Empty model for Model C
empty_model_c = fit_glm_logistic(
    formula="level1_prominence ~ 1",
    data=level1,
    model_name="Empty Model C"
)

print_model_summary(empty_model_c)
# Out:
# ======================================================================
# MODEL: Empty Model C
# ======================================================================
#
# Formula: level1_prominence ~ 1
#
# Model Fit Statistics:
#   Log-Likelihood: -13121.93
#   AIC: 26245.86
#   BIC: -160840.32
#   N observations: 18,991
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   0.8758  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model C1 - Organizational Characteristics

# %%
# Model C1: Organizational characteristics
model_c1 = fit_glm_logistic(
    formula="""level1_prominence ~ 
        level1_YEARS_EXISTED + 
        level1_OUTSIDE11 + 
        unique_issue_areas""",
    data=level1.dropna(subset=["level1_prominence", "level1_YEARS_EXISTED", "level1_OUTSIDE11", "unique_issue_areas"]),
    model_name="Model C1 (Org Chars)"
)

print_model_summary(model_c1)
# Out:
# ======================================================================
# MODEL: Model C1 (Org Chars)
# ======================================================================
#
# Formula: level1_prominence ~
#         level1_YEARS_EXISTED +
#         level1_OUTSIDE11 +
#         unique_issue_areas
#
# Model Fit Statistics:
#   Log-Likelihood: -11872.97
#   AIC: 23753.95
#   BIC: -145057.92
#   N observations: 17,302
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   0.6429  p:  0.0000 ***
#   level1_YEARS_EXISTED                     OR:   0.9998  p:  0.6938
#   level1_OUTSIDE11                         OR:   1.0270  p:  0.0000 ***
#   unique_issue_areas                       OR:   1.0362  p:  0.0000 ***
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model C notes
#
# External lobbyists increase prominence odds modestly. Organization age has minimal effect. Prominence is not simply bought, but resource advantages persist.

# %% [markdown]
# ### Model C2 - Full Model with Controls

# %%
# Model C2: Full model with controls
model_c2 = fit_glm_logistic(
    formula="""level1_prominence ~ 
        level1_YEARS_EXISTED + 
        level1_OUTSIDE11 + 
        unique_issue_areas + 
        C(level1_chamber_x, Treatment('House of Representatives')) + 
        C(level1_partyHistory, Treatment('Democrat')) + 
        C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) + 
        C(level1_ABBREVCAT, Treatment('Business Interests'))""",
    data=level1.dropna(subset=["level1_prominence", "level1_YEARS_EXISTED", "level1_OUTSIDE11", "unique_issue_areas", "level1_chamber_x", "level1_partyHistory", "level1_MSHIP_STATUS11", "level1_ABBREVCAT"]),
    model_name="Model C2 (Full)"
)

print_model_summary(model_c2)
# Out:
# ======================================================================
# MODEL: Model C2 (Full)
# ======================================================================
#
# Formula: level1_prominence ~
#         level1_YEARS_EXISTED +
#         level1_OUTSIDE11 +
#         unique_issue_areas +
#         C(level1_chamber_x, Treatment('House of Representatives')) +
#         C(level1_partyHistory, Treatment('Democrat')) +
#         C(level1_MSHIP_STATUS11, Treatment('Association of Institutions')) +
#         C(level1_ABBREVCAT, Treatment('Business Interests'))
#
# Model Fit Statistics:
#   Log-Likelihood: -7053.74
#   AIC: 14129.49
#   BIC: -82673.07
#   N observations: 10,467
#   Converged: True
#
# Fixed Effects (Odds Ratios):
# ----------------------------------------------------------------------
#   Intercept                                OR:   1.8000  p:  0.0000 ***
#   C(level1_chamber_x, Treatment('House of Representatives'))[T.Senate] OR:   1.1352  p:  0.0017 **
#   C(level1_partyHistory, Treatment('Democrat'))[T.Independent] OR:   1.0974  p:  0.6072
#   C(level1_partyHistory, Treatment('Democrat'))[T.Republican] OR:   0.8769  p:  0.0013 **
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Association of Individuals] OR:   0.8723  p:  0.0150 *
#   C(level1_MSHIP_STATUS11, Treatment('Association of Institutions'))[T.Other] OR:   0.9766  p:  0.8144
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Government Interests] OR:   0.6686  p:  0.0062 **
#   C(level1_ABBREVCAT, Treatment('Business Interests'))[T.Non-Business Interests] OR:   0.9475  p:  0.5093
#   level1_YEARS_EXISTED                     OR:   0.9990  p:  0.0961 .
#   level1_OUTSIDE11                         OR:   1.0469  p:  0.0000 ***
#   unique_issue_areas                       OR:   0.9915  p:  0.0461 *
#
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1

# %% [markdown]
# ### Model C - Comparison Table

# %%
# Compare models
model_c_comparison = compare_models([empty_model_c, model_c1, model_c2])
print("\nModel C Comparison:")
print("="*70)
display(model_c_comparison.round(2))
# Out:
# Model C Comparison:
# ======================================================================
#                   Model  Log-Likelihood        AIC          BIC      N  \
# 0         Empty Model C     -13121.9300 26245.8600 -160840.3200  18991
# 1  Model C1 (Org Chars)     -11872.9700 23753.9500 -145057.9200  17302
# 2       Model C2 (Full)      -7053.7400 14129.4900  -82673.0700  10467
#
#    Pseudo R2
# 0        NaN
# 1        NaN
# 2        NaN

# %% [markdown]
# ---
#
# # Results Summary and Visualization

# %%
# Combine all model comparisons
all_models = pd.concat([
    model_a_comparison.assign(Model_Set='A: Saliency'),
    model_b_comparison.assign(Model_Set='B: Politician'),
    model_c_comparison.assign(Model_Set='C: Organization')
])

print("\nOverall Model Comparison:")
print("="*80)
display(all_models.round(2))
# Out:
# Overall Model Comparison:
# ================================================================================
#                          Model  Log-Likelihood        AIC          BIC      N  \
# 0                Empty Model A     -13121.9300 26245.8600 -160840.3200  18991
# 1          Model A1 (Saliency)      -9813.9500 19633.9100 -118117.3800  14390
# 2              Model A2 (Full)      -4963.0400  9946.0800  -55536.7700   7362
# 0                Empty Model B     -13121.9300 26245.8600 -160840.3200  18991
# 1  Model B1 (Politician Chars)      -4904.7000  9821.3900  -54798.3300   7272
# 2              Model B2 (Full)      -4874.7600  9775.5200  -54795.9600   7272
# 0                Empty Model C     -13121.9300 26245.8600 -160840.3200  18991
# 1         Model C1 (Org Chars)     -11872.9700 23753.9500 -145057.9200  17302
# 2              Model C2 (Full)      -7053.7400 14129.4900  -82673.0700  10467
#
#    Pseudo R2        Model_Set
# 0        NaN      A: Saliency
# 1        NaN      A: Saliency
# 2        NaN      A: Saliency
# 0        NaN    B: Politician
# 1        NaN    B: Politician
# 2        NaN    B: Politician
# 0        NaN  C: Organization
# 1        NaN  C: Organization
# 2        NaN  C: Organization

# %%
# Visualize model fit comparison
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# BIC comparison
ax1 = axes[0]
for model_set in all_models['Model_Set'].unique():
    subset = all_models[all_models['Model_Set'] == model_set]
    ax1.plot(subset['Model'], subset['BIC'], marker='o', label=model_set)
ax1.set_ylabel('BIC')
ax1.set_title('BIC by Model (lower is better)')
ax1.legend()
ax1.tick_params(axis='x', rotation=45)

# AIC comparison
ax2 = axes[1]
for model_set in all_models['Model_Set'].unique():
    subset = all_models[all_models['Model_Set'] == model_set]
    ax2.plot(subset['Model'], subset['AIC'], marker='s', label=model_set)
ax2.set_ylabel('AIC')
ax2.set_title('AIC by Model (lower is better)')
ax2.legend()
ax2.tick_params(axis='x', rotation=45)

# Log-Likelihood comparison
ax3 = axes[2]
for model_set in all_models['Model_Set'].unique():
    subset = all_models[all_models['Model_Set'] == model_set]
    ax3.plot(subset['Model'], subset['Log-Likelihood'], marker='^', label=model_set)
ax3.set_ylabel('Log-Likelihood')
ax3.set_title('Log-Likelihood by Model (higher is better)')
ax3.legend()
ax3.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig(config.OUTPUT_DIR / 'model_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Create odds ratio visualization for final models
def plot_odds_ratios(model_result, title, figsize=(10, 6)):
    """
    Create a forest plot of odds ratios from a model.
    """
    if model_result is None:
        print("No model to plot")
        return
    
    df = model_result['summary_df'].copy()
    
    # Exclude intercept
    df = df[~df['term'].str.contains('Intercept', case=False)]
    
    if len(df) == 0:
        print("No coefficients to plot")
        return
    
    fig, ax = plt.subplots(figsize=figsize)
    
    # Sort by odds ratio
    df = df.sort_values('odds_ratio', ascending=True)
    
    y_pos = range(len(df))
    
    # Plot points and error bars
    ax.errorbar(
        df['odds_ratio'], y_pos,
        xerr=[df['odds_ratio'] - np.exp(df['ci_lower']),
              np.exp(df['ci_upper']) - df['odds_ratio']],
        fmt='o', color='steelblue', capsize=4, capthick=2, markersize=8
    )
    
    # Add reference line at OR = 1
    ax.axvline(x=1, color='red', linestyle='--', alpha=0.7, linewidth=2, label='OR = 1 (no effect)')
    
    # Formatting
    ax.set_yticks(y_pos)
    ax.set_yticklabels(df['term'])
    ax.set_xlabel('Odds Ratio (95% CI)', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.legend(loc='best')
    
    # Add significance markers
    for i, (_, row) in enumerate(df.iterrows()):
        sig = '***' if row['p_value'] < 0.001 else '**' if row['p_value'] < 0.01 else '*' if row['p_value'] < 0.05 else ''
        if sig:
            ax.annotate(sig, xy=(row['odds_ratio'], i), xytext=(5, 0),
                       textcoords='offset points', fontsize=12, color='red')
    
    plt.tight_layout()
    return fig

# %% [markdown]
# # Discussion
#
# Across all three model sets:
#
# - Medium-salience policy areas predict prominence better than high-salience areas (Model A)
# - Senior legislators are less likely to cite groups prominently (Model B)
# - External lobbyists modestly increase prominence, but the effect is not large (Model C)
#
# These patterns suggest prominence operates through different channels than traditional lobbying access. The medium-salience finding is particularly interesting: legislators may avoid citing external validators on highly polarized issues where group names become partisan signals.
#
# See the R Markdown notebook (`03_Multilevel_Models.Rmd`) for the primary GLMM implementation with full diagnostics.

# %%
fig_b = plot_odds_ratios(model_b2, "Model B: Politician-Group Linkage Effects on Prominence")
if fig_b:
    plt.savefig(config.OUTPUT_DIR / 'model_b_odds_ratios.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
fig_c = plot_odds_ratios(model_c2, "Model C: Organizational Characteristics Effects on Prominence")
if fig_c:
    plt.savefig(config.OUTPUT_DIR / 'model_c_odds_ratios.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ---
#
# # Export Results

# %%
def export_model_results(models: list, output_dir: Path = Path('.')):
    """
    Export model results to CSV and Excel files.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Combine all parameter-level statistics
    all_params = pd.concat([m['summary_df'] for m in models if m is not None])
    all_params.to_csv(output_dir / 'model_parameters.csv', index=False)
    print(f"Saved parameter estimates to {output_dir / 'model_parameters.csv'}")
    
    # Model-level statistics
    model_stats = []
    for m in models:
        if m is not None:
            model_stats.append({
                'Model': m['name'],
                'Formula': m['formula'],
                'Log-Likelihood': m['llf'],
                'AIC': m['aic'],
                'BIC': m['bic'],
                'N': m['nobs']
            })
    
    model_stats_df = pd.DataFrame(model_stats)
    model_stats_df.to_csv(output_dir / 'model_statistics.csv', index=False)
    print(f"Saved model statistics to {output_dir / 'model_statistics.csv'}")
    
    # Export to Excel with multiple sheets
    with pd.ExcelWriter(output_dir / 'model_results.xlsx') as writer:
        all_params.to_excel(writer, sheet_name='Parameters', index=False)
        model_stats_df.to_excel(writer, sheet_name='Model_Stats', index=False)
    print(f"Saved Excel workbook to {output_dir / 'model_results.xlsx'}")

# Export all results
all_models_list = [empty_model_a, model_a1, model_a2, 
                   empty_model_b, model_b1, model_b2,
                   empty_model_c, model_c1, model_c2]

export_model_results(all_models_list, output_dir=Path('./output'))
# Out:
# Saved parameter estimates to output\model_parameters.csv
# Saved model statistics to output\model_statistics.csv
# Saved Excel workbook to output\model_results.xlsx

# %% [markdown]
# ---
#
# # Technical Notes
#
# Mixed-effects logistic regression in Python uses `statsmodels.MixedLM` as an approximation. For true crossed random effects (Organization x Policy Area), see the R implementation in `03_Multilevel_Models.Rmd` using `lme4::glmer`.

# %%
# Session info
import sys
print(f"Python version: {sys.version}")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Statsmodels version: {sm.__version__}")
# Out:
# Python version: 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
# Pandas version: 2.3.2
# NumPy version: 2.3.3
# Statsmodels version: 0.14.6
